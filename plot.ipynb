# %%
from exp.plot import RecordPloter, LogPloter, Subplots
import matplotlib
import matplotlib.pyplot as plt
config = {
    'font.family':'Times New Roman',
    'font.size': 18,
    'axes.unicode_minus':False
}
plt.rcParams.update(config)
print(matplotlib.matplotlib_fname())
# Out:
# /mnt/ssd/qucheng/anaconda3/envs/arrl/lib/python3.10/site-packages/matplotlib/mpl-data/matplotlibrc

# %%
ab_ploter = RecordPloter("/mnt/ssd/qucheng/ARRL/records/test_harmony_ablation", debug=False)
ab_ploter.set_methods(None)
ab_ploter.set_params(["[16,3200]"])
ab_ploter.plot_actual_throughput()
ab_ploter.plot_tx_delay()
ab_ploter.plot_cross_rate()
ab_ploter.plot_utility()
ab_ploter.plot_avg_queue_length()
ab_ploter.plot_queue_length_std()
ab_ploter.plot_avg_local_graph_size_mb()
ab_ploter.plot_avg_partition_time()
ab_ploter.plot_avg_state_migration_size_mb()
ab_ploter.plot_allocation_table_size_mb()
# Out:
# TAB-5,5 : avg.: [2010.013814814815] std.: [74.93873051299877]
# TAB-1,1 : avg.: [2011.3817037037036] std.: [58.94782616056536]
# TAB-P-1,1 : avg.: [2003.4669999999999] std.: [58.2583055447591]
# TAB-S-P : avg.: [1745.3282592592593] std.: [8.247200058767165]
# Transformers : avg.: [2315.81] std.: [20.92726215943478]
# Monoxide : avg.: [1503.2822222222221] std.: [10.34226053606678]
# Params: ['[16,3200]']
# TAB-5,5 : avg.: [1442.7645283268505] std.: [88.90541527717666]
# TAB-1,1 : avg.: [1498.8727831608749] std.: [142.75980609659024]
# TAB-P-1,1 : avg.: [1483.056307747848] std.: [65.36809853667752]
# TAB-S-P : avg.: [2002.8924479130228] std.: [11.169627914362966]
# Transformers : avg.: [1558.4358158211091] std.: [37.010250805311586]
# Monoxide : avg.: [2017.7612505921195] std.: [55.7882607348589]
# Params: ['[16,3200]']
# TAB-5,5 : avg.: [0.5785302991171148] std.: [0.0556951979528993]
# TAB-1,1 : avg.: [0.574037464757767] std.: [0.04472627845157636]
# ...

# %%
cost_ploter = RecordPloter("/mnt/ssd/qucheng/ARRL/records/test_harmony_overhead", debug=False)
cost_ploter.set_params(["[16,3200]"])

# %%
subplots = Subplots(3, 2, projection='3d', figsize=(10, 15))
cost_ploter.plot_surface_actual_throughput(ax=subplots[0,0], elev=20, azim=25)
cost_ploter.plot_surface_tx_delay(ax=subplots[0,1], elev=20, azim=25)
cost_ploter.plot_surface_local_graph_size(ax=subplots[1,0], elev=20, azim=25)
cost_ploter.plot_surface_partition_time(ax=subplots[1,1], elev=20, azim=25)
cost_ploter.plot_surface_state_migration_size(ax=subplots[2,0], elev=20, azim=25)
cost_ploter.plot_surface_allocation_table_size(ax=subplots[2,1], elev=20, azim=25)
subplots.show(save_path='./images/overheads.png', remove_title=False, titley=-0.09, adjust_kw=dict(wspace=0, hspace=0.1, left=0, right=1, top=1, bottom=0), layout_kw=dict(pad=1, rect=(0,0,1,1)), save_kw=dict(bbox_inches=matplotlib.transforms.Bbox([[-0.5,-0.5],[10,14.5]])))
# Out:
# TAB-1,1 : avg.: [2025.227111111111] std.: [60.75139484947126]
# TAB-1,2 : avg.: [2044.2518518518518] std.: [64.60027369422677]
# TAB-1,3 : avg.: [2045.5348888888886] std.: [47.79575160373837]
# TAB-1,4 : avg.: [2050.9415185185185] std.: [65.0253034499643]
# TAB-1,5 : avg.: [2059.3790740740737] std.: [55.411824145338]
# TAB-1,6 : avg.: [2050.6791851851854] std.: [67.47585424110265]
# TAB-1,7 : avg.: [2068.6607407407405] std.: [63.252661994070145]
# TAB-1,8 : avg.: [2066.488074074074] std.: [49.178907728255915]
# TAB-1,9 : avg.: [2053.469888888889] std.: [64.31280668750746]
# TAB-1,10 : avg.: [2053.493740740741] std.: [47.87029609269981]
# TAB-2,2 : avg.: [2003.2034074074074] std.: [69.01178658097035]
# TAB-2,3 : avg.: [2034.1945555555556] std.: [52.746247332512176]
# TAB-2,4 : avg.: [2048.674592592593] std.: [72.08254779426879]
# TAB-2,5 : avg.: [2044.7456666666665] std.: [58.47187013480691]
# TAB-2,6 : avg.: [2044.2050740740742] std.: [77.85327770699763]
# ...

# %%
cost_ploter.plot_map_partition_time()
cost_ploter.plot_map_actual_throughput()
cost_ploter.plot_map_tx_delay()
cost_ploter.plot_map_allocation_table_size()
cost_ploter.plot_map_state_migration_size()
cost_ploter.plot_map_local_graph_size()
# Out:
# TAB-1,1 : avg.: [55.25881295203703] std.: [1.1000198160729786]
# TAB-1,2 : avg.: [49.465026411] std.: [4.095283694439299]
# TAB-1,3 : avg.: [46.16031355022222] std.: [5.207360895092357]
# TAB-1,4 : avg.: [45.21509744507407] std.: [6.6028027778141976]
# TAB-1,5 : avg.: [47.16573441125926] std.: [3.7134666068322137]
# TAB-1,6 : avg.: [48.174617320185185] std.: [6.892496015080661]
# TAB-1,7 : avg.: [43.82347084551852] std.: [2.7408501198826163]
# TAB-1,8 : avg.: [44.82129586737036] std.: [0.3391635667473407]
# TAB-1,9 : avg.: [45.059125544185186] std.: [5.494327154967188]
# TAB-1,10 : avg.: [46.32592488459259] std.: [2.8901988516054993]
# TAB-2,2 : avg.: [34.382913723407405] std.: [1.7006062210470922]
# TAB-2,3 : avg.: [32.88978149803704] std.: [0.9805708083707689]
# TAB-2,4 : avg.: [30.52669733448148] std.: [1.6712913681862405]
# TAB-2,5 : avg.: [31.761507493370374] std.: [3.3091590192431464]
# TAB-2,6 : avg.: [30.051627555666666] std.: [1.761503430111365]
# ...

# %%
d = {'TAB-1,1': 1499.5345365002624, 'TAB-1,2': 1386.116326776518, 'TAB-1,3': 1425.758292911282, 'TAB-1,4': 1320.5188547482821, 'TAB-1,5': 1351.5521639047827, 'TAB-1,6': 1347.210275589136, 'TAB-1,7': 1339.9933808009825, 'TAB-1,8': 1386.060041719192, 'TAB-1,9': 1306.5436336997934, 'TAB-1,10': 1372.0717922055646, 'TAB-2,2': 1475.2545424508305, 'TAB-2,3': 1436.5689968502566, 'TAB-2,4': 1390.5858363031448, 'TAB-2,5': 1418.8559900749617, 'TAB-2,6': 1388.1233009045297, 'TAB-2,7': 1343.6685546226881, 'TAB-2,8': 1348.263665839283, 'TAB-2,9': 1308.1579532420174, 'TAB-2,10': 1361.8635870248984, 'TAB-3,3': 1379.9631186522, 'TAB-3,4': 1389.5870166436177, 'TAB-3,5': 1334.9208801576026, 'TAB-3,6': 1400.1078547663349, 'TAB-3,7': 1411.651332930368, 'TAB-3,8': 1370.1068845031848, 'TAB-3,9': 1366.009532667238, 'TAB-3,10': 1324.8916957174745, 'TAB-4,4': 1436.0417715941373, 'TAB-4,5': 1343.8849326300485, 'TAB-4,6': 1415.5379380348706, 'TAB-4,7': 1402.215895428699, 'TAB-4,8': 1376.149263034582, 'TAB-4,9': 1384.8720884113116, 'TAB-4,10': 1335.1744011093526, 'TAB-5,5': 1406.8002514733405, 'TAB-5,6': 1395.9749816993515, 'TAB-5,7': 1369.3589989992518, 'TAB-5,8': 1389.2019419306678, 'TAB-5,9': 1369.2932515687096, 'TAB-5,10': 1331.6671641647106, 'TAB-6,6': 1429.3755545123895, 'TAB-6,7': 1397.0720113162815, 'TAB-6,8': 1409.2631413116014, 'TAB-6,9': 1393.1075386497832, 'TAB-6,10': 1377.2634422251394, 'TAB-7,7': 1368.4985740128243, 'TAB-7,8': 1383.6332216215262, 'TAB-7,9': 1433.5126994855516, 'TAB-7,10': 1403.2434697295096, 'TAB-8,8': 1375.6666508384567, 'TAB-8,9': 1419.0735439139344, 'TAB-8,10': 1391.0448885921203, 'TAB-9,9': 1435.3798130753503, 'TAB-9,10': 1375.0859790733384, 'TAB-10,10': 1424.669370547875}
x = {'TAB-1,1': 2025.227111111111, 'TAB-1,2': 2044.2518518518518, 'TAB-1,3': 2045.5348888888886, 'TAB-1,4': 2050.9415185185185, 'TAB-1,5': 2059.3790740740737, 'TAB-1,6': 2050.6791851851854, 'TAB-1,7': 2068.6607407407405, 'TAB-1,8': 2066.488074074074, 'TAB-1,9': 2053.469888888889, 'TAB-1,10': 2053.493740740741, 'TAB-2,2': 2003.2034074074074, 'TAB-2,3': 2034.1945555555556, 'TAB-2,4': 2048.674592592593, 'TAB-2,5': 2044.7456666666665, 'TAB-2,6': 2044.2050740740742, 'TAB-2,7': 2053.227, 'TAB-2,8': 2055.4004074074073, 'TAB-2,9': 2045.0248888888889, 'TAB-2,10': 2039.2214444444444, 'TAB-3,3': 2026.7666666666664, 'TAB-3,4': 2038.2669999999998, 'TAB-3,5': 2046.4957037037038, 'TAB-3,6': 2030.904111111111, 'TAB-3,7': 2045.0741851851851, 'TAB-3,8': 2037.5004074074075, 'TAB-3,9': 2031.2954074074075, 'TAB-3,10': 2043.4117037037038, 'TAB-4,4': 2043.5011111111114, 'TAB-4,5': 2051.608111111111, 'TAB-4,6': 2041.6061851851853, 'TAB-4,7': 2029.2372592592592, 'TAB-4,8': 2030.7462592592592, 'TAB-4,9': 2043.3778148148149, 'TAB-4,10': 2049.064185185185, 'TAB-5,5': 2020.8914814814816, 'TAB-5,6': 2026.9476296296295, 'TAB-5,7': 2024.8613703703704, 'TAB-5,8': 2024.3900370370368, 'TAB-5,9': 2035.4464814814812, 'TAB-5,10': 2055.6717037037038, 'TAB-6,6': 2018.847962962963, 'TAB-6,7': 2008.835074074074, 'TAB-6,8': 2018.133074074074, 'TAB-6,9': 2009.1854814814815, 'TAB-6,10': 2020.979185185185, 'TAB-7,7': 2018.936851851852, 'TAB-7,8': 2033.8488518518518, 'TAB-7,9': 1998.0597037037035, 'TAB-7,10': 2014.3722962962966, 'TAB-8,8': 2031.5662592592591, 'TAB-8,9': 2023.4247777777775, 'TAB-8,10': 2021.2785555555556, 'TAB-9,9': 2003.2105925925928, 'TAB-9,10': 2013.0232592592595, 'TAB-10,10': 2020.7084814814814}
print(max(d.values())/min(d.values()))
print(max(x.values())/min(x.values()))
# Out:
# 1.147711027647786
# 1.035334798507856

# %%
logploter = LogPloter("/mnt/ssd/qucheng/ARRL/logs/test_stack.log")
logploter.plot_new_accounts(key=slice(0,100), type='Vertex')
logploter.plot_new_accounts_ratio(key=slice(0,100), type='Vertex')
logploter.plot_cost_and_coverage(key=100, type='Vertex')
logploter.plot_new_accounts(key=slice(0,100), type='Edge')
logploter.plot_new_accounts_ratio(key=slice(0,100), type='Edge')
logploter.plot_cost_and_coverage(key=100, type='Edge')
# Out:
# Coverage: [0.17163288132611132, 0.2140352641037564, 0.2385039775797715, 0.2570283143356248, 0.2762564250794888, 0.2966281685538701, 0.324402106295007, 0.3406768797677546, 0.35295522238001287, 0.361840368978648]
# Cost: [79571, 147895, 223198, 301950, 382371, 450153, 514086, 572055, 626097, 678504]
# Coverage: [0.07959337349397588, 0.10221197289156625, 0.11592620481927707, 0.12648719879518078, 0.1386012801204819, 0.1522025602409639, 0.17573418674698793, 0.1866246234939759, 0.19446536144578308, 0.2006588855421687]
# Cost: [106240, 205365, 308489, 416785, 527608, 627211, 724114, 818060, 906578, 992872]

# %%
ploter = RecordPloter("/mnt/ssd/qucheng/ARRL/records/test_harmony_performance", debug=False)
ploter.set_params(["[2,400]","[4,800]","[8,1600]","[16,3200]","[32,6400]"])
ploter.set_methods(["TAB-5,5","TAB-1,1","Transformers","Monoxide"])
ploter.plot_actual_throughput()
ploter.plot_tx_delay()
ploter.plot_cross_rate()
ploter.plot_utility()
ploter.plot_avg_partition_time()
ploter.plot_avg_queue_length()
ploter.plot_queue_length_std()
ploter.plot_local_graph_size()
ploter.plot_state_migration_size()
ploter.plot_allocation_table_size()
# Out:
# TAB-5,5 : avg.: [336.46074074074073, 597.8618518518518, 1100.6750555555554, 2019.4755925925926, 3720.9834444444446] std.: [4.323429179604567, 17.460879602602265, 31.49616666666668, 82.72166608634952, 122.8218364000936]
# TAB-1,1 : avg.: [343.048, 586.6144074074074, 1115.2055555555555, 2020.875925925926, 3708.459722222222] std.: [9.325123842335655, 18.141588956169063, 28.649910198438654, 42.078671417354066, 113.00205555555544]
# Transformers : avg.: [358.30266666666665, 694.356037037037, 1313.0128333333334, 2299.957722222222, 4167.834866666666] std.: [2.7864601110759324, 6.675633407676751, 9.454921033841156, 28.22082157465943, 41.12200989307816]
# Monoxide : avg.: [266.5232222222223, 459.15768518518513, 852.072685185185, 1503.283074074074, 2834.595481481482] std.: [1.2656777523680824, 0.8225050725115898, 1.8562062292484258, 10.34297559282891, 9.738793108625966]
# Params: ['[2,400]', '[4,800]', '[8,1600]', '[16,3200]', '[32,6400]']
# ...

# %%
ploter.set_params(["[2,300]","[4,600]","[8,1200]","[16,2400]","[32,4800]"])
ploter.plot_actual_throughput()
ploter.plot_tx_delay()
ploter.plot_cross_rate()
ploter.plot_utility()
ploter.plot_avg_partition_time()
ploter.plot_avg_queue_length()
ploter.plot_queue_length_std()
ploter.plot_local_graph_size()
ploter.plot_state_migration_size()
ploter.plot_allocation_table_size()
# Out:
# TAB-5,5 : avg.: [301.3002222222222, 588.6513703703704, 1105.340148148148, 2030.0612962962962, 3706.2864444444444] std.: [0.4840989933793935, 2.1894247705250542, 8.970431574706344, 42.01177526038976, 44.68230786128551]
# TAB-1,1 : avg.: [301.3472962962963, 595.453238095238, 1138.6699629629632, 2041.901740740741, 3744.1694074074076] std.: [0.20930734943974846, 4.929318393923479, 10.790311164723176, 38.54823242443184, 73.87117453934025]
# Transformers : avg.: [297.7183333333333, 584.7347777777778, 1154.148037037037, 2139.1751481481483, 3932.485925925926] std.: [0.9162326829021635, 2.1092143158015846, 3.0803746356161543, 21.032089847090333, 33.234686789598975]
# Monoxide : avg.: [266.52299999999997, 459.0488888888889, 849.2312592592592, 1470.9606666666666, 2780.8078888888886] std.: [1.265798282579445, 0.8506615560212071, 3.8145492539714203, 12.807836463369927, 31.610186643905788]
# Params: ['[2,300]', '[4,600]', '[8,1200]', '[16,2400]', '[32,4800]']
# ...

# %%
ploter.set_params(["[2,200]","[4,400]","[8,800]","[16,1600]","[32,3200]"])
ploter.plot_actual_throughput()
ploter.plot_tx_delay()
ploter.plot_cross_rate()
ploter.plot_utility()
ploter.plot_avg_partition_time()
ploter.plot_avg_queue_length()
ploter.plot_queue_length_std()
ploter.plot_local_graph_size()
ploter.plot_state_migration_size()
ploter.plot_allocation_table_size()
# Out:
# TAB-5,5 : avg.: [200.0488888888889, 400.48203703703706, 807.955962962963, 1610.4038518518519, 2891.192703703704] std.: [0.013200573625139001, 0.5286584646922925, 1.836722282623094, 17.67787185354148, 31.941369153656392]
# TAB-1,1 : avg.: [200.05055555555555, 400.4807037037037, 808.0903333333332, 1624.0133703703705, 2951.1464444444446] std.: [0.01690958770576393, 0.5129437060164024, 1.918826628340784, 10.795859544053153, 26.09988682109706]
# Transformers : avg.: [199.99722222222223, 399.6723703703704, 801.7634074074073, 1615.308962962963, 2945.480666666667] std.: [0.005675012010290414, 0.49852812439153543, 0.590064196363342, 10.606354473268338, 23.300449639597193]
# Monoxide : avg.: [199.99722222222223, 399.954, 739.4967777777778, 1220.633074074074, 2330.0508888888885] std.: [0.005675012010290414, 0.20573531679352453, 6.5874309504349755, 14.515488049085908, 14.287250461044806]
# Params: ['[2,200]', '[4,400]', '[8,800]', '[16,1600]', '[32,3200]']
# ...

# %%
subplots = Subplots(1, 2, figsize=(12,5))
logploter.plot_new_ve_ratio(key=(0,100), ax=subplots[0,0])
logploter.plot_vpe_cost_and_coverage(key=100, ax=subplots[0,1])
subplots.show(save_path='./images/cost_and_coverage.png', titley=-0.32, save_kw=dict(bbox_inches='tight'))
# Out:
# VCoverage: [0.17163288132611132, 0.2140352641037564, 0.2385039775797715, 0.2570283143356248, 0.2762564250794888, 0.2966281685538701, 0.324402106295007, 0.3406768797677546, 0.35295522238001287, 0.361840368978648]
# ECoverage: [0.07959337349397588, 0.10221197289156625, 0.11592620481927707, 0.12648719879518078, 0.1386012801204819, 0.1522025602409639, 0.17573418674698793, 0.1866246234939759, 0.19446536144578308, 0.2006588855421687]
# Cost: [185811, 353260, 531687, 718735, 909979, 1077364, 1238200, 1390115, 1532675, 1671376]

# %%
subplots = Subplots(1, 3)
ploter.set_params(["[2,200]","[4,400]","[8,800]","[16,1600]","[32,3200]"])
ploter.plot_actual_throughput(ax=subplots[0,0], title='Actual Throughput at 50% Load')
ploter.set_params(["[2,300]","[4,600]","[8,1200]","[16,2400]","[32,4800]"])
ploter.plot_actual_throughput(ax=subplots[0,1], title='Actual Throughput at 75% Load')
ploter.set_params(["[2,400]","[4,800]","[8,1600]","[16,3200]","[32,6400]"])
ploter.plot_actual_throughput(ax=subplots[0,2], title='Actual Throughput at 100% Load')
subplots.show(save_path='./images/throughput.png', titley=-0.3, save_kw=dict(bbox_inches='tight'))
# Out:
# TAB-5,5 : avg.: [200.0488888888889, 400.48203703703706, 807.955962962963, 1610.4038518518519, 2891.192703703704] std.: [0.013200573625139001, 0.5286584646922925, 1.836722282623094, 17.67787185354148, 31.941369153656392]
# TAB-1,1 : avg.: [200.05055555555555, 400.4807037037037, 808.0903333333332, 1624.0133703703705, 2951.1464444444446] std.: [0.01690958770576393, 0.5129437060164024, 1.918826628340784, 10.795859544053153, 26.09988682109706]
# Transformers : avg.: [199.99722222222223, 399.6723703703704, 801.7634074074073, 1615.308962962963, 2945.480666666667] std.: [0.005675012010290414, 0.49852812439153543, 0.590064196363342, 10.606354473268338, 23.300449639597193]
# Monoxide : avg.: [199.99722222222223, 399.954, 739.4967777777778, 1220.633074074074, 2330.0508888888885] std.: [0.005675012010290414, 0.20573531679352453, 6.5874309504349755, 14.515488049085908, 14.287250461044806]
# Params: ['[2,200]', '[4,400]', '[8,800]', '[16,1600]', '[32,3200]']
# ...

# %%
subplots = Subplots(1, 3)
ploter.set_params(["[2,200]","[4,400]","[8,800]","[16,1600]","[32,3200]"])
ploter.plot_tx_delay(ax=subplots[0,0], title='Transaction Latency at 50% Load')
ploter.set_params(["[2,300]","[4,600]","[8,1200]","[16,2400]","[32,4800]"])
ploter.plot_tx_delay(ax=subplots[0,1], title='Transaction Latency at 75% Load')
ploter.set_params(["[2,400]","[4,800]","[8,1600]","[16,3200]","[32,6400]"])
ploter.plot_tx_delay(ax=subplots[0,2], title='Transaction Latency at 100% Load')
subplots.show(save_path='./images/delay.png', titley=-0.3, save_kw=dict(bbox_inches='tight'))
# Out:
# TAB-5,5 : avg.: [6.894026526218343, 8.373494715671228, 16.769771274094293, 144.6982090699868, 234.29538899852938] std.: [0.11148142295809911, 0.13436120308324334, 4.70590823769195, 34.679314930843184, 33.60177786944989]
# TAB-1,1 : avg.: [6.670803913682653, 8.111674281522276, 17.71561212306142, 94.88622056669728, 320.9549241992827] std.: [0.19619137620598087, 0.2143975091927002, 5.024946955715435, 19.50159962995485, 25.936812420629963]
# Transformers : avg.: [9.93122295767449, 16.30768088636106, 59.902682222139504, 195.86707620439668, 424.4475543157518] std.: [0.035439042387623694, 0.9878968830756898, 3.5899697072903183, 41.498412497348085, 10.9767390072039]
# Monoxide : avg.: [9.932489593378952, 16.231605390457762, 318.3059443405939, 499.3216002833051, 569.7536163228623] std.: [0.033722565949861734, 3.4801635505178163, 1.1265504288782962, 46.000674215478945, 17.990816587914274]
# Params: ['[2,200]', '[4,400]', '[8,800]', '[16,1600]', '[32,3200]']
# ...

# %%
subplots = Subplots(1, 3)
ploter.set_params(["[2,200]","[4,400]","[8,800]","[16,1600]","[32,3200]"])
ploter.plot_cross_rate(ax=subplots[0,0], title='Cross Rate at 50% Load')
ploter.set_params(["[2,300]","[4,600]","[8,1200]","[16,2400]","[32,4800]"])
ploter.plot_cross_rate(ax=subplots[0,1], title='Cross Rate at 75% Load')
ploter.set_params(["[2,400]","[4,800]","[8,1600]","[16,3200]","[32,6400]"])
ploter.plot_cross_rate(ax=subplots[0,2], title='Cross Rate at 100% Load')
subplots.show(save_path='./images/cross_rate.png', titley=-0.3, save_kw=dict(bbox_inches='tight'))
# Out:
# TAB-5,5 : avg.: [0.1881983338679366, 0.32000962911416103, 0.4195514869288129, 0.5300226755247611, 0.5727675225927454] std.: [0.011629506587911608, 0.022263428995880633, 0.029395261120406645, 0.041253816365779544, 0.040832928595410094]
# TAB-1,1 : avg.: [0.1663207199658516, 0.29374511851222485, 0.3890485661300133, 0.5081624685749585, 0.5671848629463004] std.: [0.019605491070541787, 0.022828826007096136, 0.03117927161505715, 0.034328870200308004, 0.03782070690660266]
# Transformers : avg.: [0.49252518518518523, 0.7007505903756007, 0.7471491447830839, 0.7505294910601915, 0.8005723716984369] std.: [0.0038842140243691065, 0.011497962003484824, 0.0009888204458012861, 0.011615490848038437, 0.013461511972709846]
# Monoxide : avg.: [0.49252518518518523, 0.7386810484195371, 0.8647884649929614, 0.9442619398034641, 0.9673255978364151] std.: [0.0038842140243691065, 0.001296814936276153, 0.0030151159068549723, 0.001346294639434871, 0.0011239905912075164]
# ...

# %%
subplots = Subplots(1, 3)
ploter.set_params(["[2,200]","[4,400]","[8,800]","[16,1600]","[32,3200]"])
ploter.plot_utility(ax=subplots[0,0], title='Utilization at 50% Load')
ploter.set_params(["[2,300]","[4,600]","[8,1200]","[16,2400]","[32,4800]"])
ploter.plot_utility(ax=subplots[0,1], title='Utilization at 75% Load')
ploter.set_params(["[2,400]","[4,800]","[8,1600]","[16,3200]","[32,6400]"])
ploter.plot_utility(ax=subplots[0,2], title='Utilization at 100% Load')
subplots.show(save_path='./images/utility.png', titley=-0.3, save_kw=dict(bbox_inches='tight'))
# Out:
# TAB-5,5 : avg.: [0.5943221296296296, 0.6610227777777778, 0.717195324074074, 0.7702656134259259, 0.7248825] std.: [0.005790863592663356, 0.01043711405055143, 0.01652318760463518, 0.01707862275662935, 0.0149204930082837]
# TAB-1,1 : avg.: [0.5834325925925926, 0.6480123148148148, 0.7021230555555555, 0.7661116782407408, 0.7447188310185185] std.: [0.009800026203913603, 0.010845493048339977, 0.01749155446625491, 0.014687571555001857, 0.015285434968645616]
# Transformers : avg.: [0.7462556481481482, 0.85001375, 0.8760001388888888, 0.8827995254629629, 0.8619984953703703] std.: [0.0019279480970408143, 0.004638939907404048, 0.0001343736900596469, 0.008021381369832088, 0.00463555472663241]
# Monoxide : avg.: [0.7462556481481482, 0.8692571759259259, 0.8618674305555555, 0.7876664814814814, 0.8043813657407407] std.: [0.0019279480970408143, 0.0009069884449462992, 0.006554767786304973, 0.0056088827899078144, 0.0021718401553891295]
# ...

# %%
from matplotlib.ticker import ScalarFormatter
y_formatter = ScalarFormatter(useMathText=True)
y_formatter.set_powerlimits((2,-2))
subplots = Subplots(1, 3, gridspec_kw=dict(width_ratios=[1,1,1]))
ploter.set_params(["[2,200]","[4,400]","[8,800]","[16,1600]","[32,3200]"])
ploter.plot_avg_queue_length(ax=subplots[0,0], title='Avg. Queue Length at 50% Load', y_formatter=y_formatter)
ploter.set_params(["[2,300]","[4,600]","[8,1200]","[16,2400]","[32,4800]"])
ploter.plot_avg_queue_length(ax=subplots[0,1], title='Avg. Queue Length at 75% Load', y_formatter=y_formatter)
ploter.set_params(["[2,400]","[4,800]","[8,1600]","[16,3200]","[32,6400]"])
ploter.plot_avg_queue_length(ax=subplots[0,2], title='Avg. Queue Length at 100% Load')
subplots.show(save_path='./images/queue_length.png', titley=-0.3, layout_kw=dict(pad=1), save_kw=dict(bbox_inches='tight'))
# Out:
# TAB-5,5 : avg.: [182.83333333333334, 355.8333333333333, 767.625, 16022.916666666666, 113385.16666666667] std.: [26.584247633179732, 18.98391131692542, 441.2112943363984, 10290.128099063631, 9661.948145670109]
# TAB-1,1 : avg.: [175.33333333333334, 340.4166666666667, 644.0, 8368.270833333334, 96523.17708333333] std.: [29.229931387002758, 20.443349910314492, 296.55360673353255, 6427.431175352163, 8119.531702982496]
# Transformers : avg.: [470.1666666666667, 1653.8333333333333, 6398.041666666667, 17507.979166666668, 100376.60416666667] std.: [17.441967269268172, 1084.6574792173897, 562.4154133931805, 6745.940367626769, 7074.065106459322]
# Monoxide : avg.: [495.8333333333333, 1063.0833333333333, 76473.58333333333, 239498.6875, 273467.4583333333] std.: [38.055515004033545, 417.80290076648447, 7828.79996746344, 9151.880434762437, 4065.5423673172304]
# Params: ['[2,200]', '[4,400]', '[8,800]', '[16,1600]', '[32,3200]']
# ...

# %%
subplots = Subplots(1, 3)
ploter.set_params(["[2,200]","[4,400]","[8,800]","[16,1600]","[32,3200]"])
ploter.plot_queue_length_std(ax=subplots[0,0], title='Queue Length Std. at 50% Load')
ploter.set_params(["[2,300]","[4,600]","[8,1200]","[16,2400]","[32,4800]"])
ploter.plot_queue_length_std(ax=subplots[0,1], title='Queue Lengbth Std. at 75% Load')
ploter.set_params(["[2,400]","[4,800]","[8,1600]","[16,3200]","[32,6400]"])
ploter.plot_queue_length_std(ax=subplots[0,2], title='Queue Length Std. at 100% Load')
subplots.show(save_path='./images/queue_length_std.png', titley=-0.3, save_kw=dict(bbox_inches='tight'))
# Out:
# TAB-5,5 : avg.: [23.166666666666668, 148.4638069491647, 907.8548860457055, 42254.46562196298, 432428.9725097549] std.: [17.196575886560158, 24.78066503333764, 1032.0728336740285, 26709.245931735542, 38904.47915961688]
# TAB-1,1 : avg.: [23.333333333333332, 189.26763760784823, 566.4617663480914, 25432.52491054436, 371096.4996578223] std.: [17.8060539018491, 26.316797950059108, 484.1190717159711, 21461.769620260446, 31643.593656711262]
# Transformers : avg.: [97.83333333333333, 1370.3743323783856, 10997.206517772885, 38257.279861359006, 356371.1025853047] std.: [17.78263822446552, 1554.9620512492131, 1609.0633139071722, 16447.406984683355, 30315.28865305313]
# Monoxide : avg.: [123.5, 596.2648554895937, 141248.982377179, 717756.9535672534, 1086961.8411856645] std.: [23.03620339089466, 640.2771805564425, 24186.065105907874, 39437.25166159445, 5873.185674359333]
# Params: ['[2,200]', '[4,400]', '[8,800]', '[16,1600]', '[32,3200]']
# ...
